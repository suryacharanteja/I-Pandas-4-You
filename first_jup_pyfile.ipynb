# %%
name = "charan"

# %%
age = "25"

# %%
print(age)
# Out:
# 25

# %% [markdown]
# # Jupyter Notebook

# %% [markdown]
# ## Jupyter Notebook

# %% [markdown]
# ### Jupyter Notebook

# %% [markdown]
# #### Jupyter Notebook

# %% [markdown]
# ##### Jupyter Notebook

# %% [markdown]
# ###### Jupyter Notebook

# %% [markdown]
# # Jupyter Notebook

# %% [markdown]
# # Jupyter Notebook

# %% [markdown]
# # Jupyter Notebook

# %% [markdown]
# # Jupyter Notebook

# %% [markdown]
# # Jupyter Notebook

# %%
print(name)
# Out:
# charan

# %% [markdown]
# # Analyze the Users data _ read from CSV file

# %%
import pandas as pd

# %%
users = pd.read_csv("userdata.csv")

# %%
users
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Want to see first 8 rows of users Dataframe

# %%
top8df = users.head(8)

# %%
top8df.shape
# Out:
# (8, 12)

# %%
bottom15usersdf = users.tail(15)

# %%
bottom15usersdf
# Out:
#      PassengerId  Survived  Pclass  \
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                               Name     Sex   Age  SibSp  \
# 876                  Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                           Petroff, Mr. Nedelio    male  19.0      0
# 878                             Laleff, Mr. Kristo    male   NaN      0
# 879  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# ...

# %%
bottom15usersdf.shape
# Out:
# (15, 12)

# %% [markdown]
# ### find out the data types of each series in our dataframe

# %%
users.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ### write the dataframe to excel spreadsheet

# %%
users.to_excel("users.xlsx", index=False)

# %%
users_excel = pd.read_excel("users.xlsx")

# %%
users_excel
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
info_df = users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
info_df

# %%
stats = users.describe()

# %%
stats
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
stats.to_excel("users.xlsx", sheet_name="statistics", index=False)

# %%
users_excel = pd.read_excel("users.xlsx", sheet_name="statistics")

# %%
users_excel
# Out:
#    PassengerId    Survived      Pclass         Age       SibSp       Parch  \
# 0   891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# 1   446.000000    0.383838    2.308642   29.699118    0.523008    0.381594
# 2   257.353842    0.486592    0.836071   14.526497    1.102743    0.806057
# 3     1.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 4   223.500000    0.000000    2.000000   20.125000    0.000000    0.000000
# 5   446.000000    0.000000    3.000000   28.000000    0.000000    0.000000
# 6   668.500000    1.000000    3.000000   38.000000    1.000000    0.000000
# 7   891.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#          Fare
# 0  891.000000
# 1   32.204208
# 2   49.693429
# 3    0.000000
# 4    7.910400
# 5   14.454200
# 6   31.000000
# 7  512.329200

# %%
users.to_excel("users.xlsx", sheet_name="passengers", index=False)

# %% [markdown]
# ### write a excel workbook with multiple sheets

# %%
with pd.ExcelWriter('users.xlsx') as writer:
    users.to_excel(writer, sheet_name='PassengerInfo')
    stats.to_excel(writer, sheet_name='StatistcalAnalysis')
