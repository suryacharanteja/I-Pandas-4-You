# %%
import pandas as pd

# %%
titanic_df = pd.read_csv("./userdata.csv")

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.shape
# Out:
# (891, 12)

# %%
airquality_df = pd.read_csv("./Airquality.csv")

# %%
airquality_df
# Out:
#                  datetime  station_antwerp  station_paris  station_london
# 0     2019-05-07 02:00:00              NaN            NaN            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00              NaN           50.4            16.0
# 4     2019-05-07 06:00:00              NaN           61.9             NaN
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 4 columns]

# %%
airquality_df = pd.read_csv("./Airquality.csv", index_col="datetime", parse_dates=True)

# %%
airquality_df
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 3 columns]

# %% [markdown]
# # Sort table rows

# %% [markdown]
# ### I want to sort the Titanic data according to the age of the passengers

# %%
titanic_sort = titanic_df.sort_values(by="Age").head(50)

# %%
titanic_sort.shape
# Out:
# (50, 12)

# %% [markdown]
# ### I want to sort the Titanic data according to the cabin class and age in descending order.

# %%
titanic_df.sort_values(by=['Pclass', 'Age'], ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass                       Name     Sex   Age  \
# 851          852         0       3        Svensson, Mr. Johan    male  74.0
# 116          117         0       3       Connors, Mr. Patrick    male  70.5
# 280          281         0       3           Duane, Mr. Frank    male  65.0
# 483          484         1       3     Turkula, Mrs. (Hedwig)  female  63.0
# 326          327         0       3  Nysveen, Mr. Johan Hansen    male  61.0
#
#      SibSp  Parch  Ticket    Fare Cabin Embarked
# 851      0      0  347060  7.7750   NaN        S
# 116      0      0  370369  7.7500   NaN        Q
# 280      0      0  336439  7.7500   NaN        Q
# 483      0      0    4134  9.5875   NaN        S
# 326      0      0  345364  6.2375   NaN        S

# %%
titanic_df.sort_values(by=['Pclass', 'Age'], ascending=False).head(50)
# Out:
#      PassengerId  Survived  Pclass  \
# 851          852         0       3
# 116          117         0       3
# 280          281         0       3
# 483          484         1       3
# 326          327         0       3
# 94            95         0       3
# 152          153         0       3
# 222          223         0       3
# 406          407         0       3
# 631          632         0       3
# 482          483         0       3
# 597          598         0       3
# 736          737         0       3
# 771          772         0       3
# 132          133         0       3
# 592          593         0       3
# 873          874         0       3
# 203          204         0       3
# 129          130         0       3
# 167          168         0       3
# 276          277         0       3
# 338          339         1       3
# 362          363         0       3
# 160          161         0       3
# 414          415         1       3
# ...

# %% [markdown]
# ### filter for no2 data only

# %%
    aql_df = pd.read_csv("./Airqualitylong.csv")

# %%
aql_df
# Out:
#            city country                   date.utc            location  \
# 0     Antwerpen      BE  2019-06-18 06:00:00+00:00             BETR801
# 1     Antwerpen      BE  2019-06-17 08:00:00+00:00             BETR801
# 2     Antwerpen      BE  2019-06-17 07:00:00+00:00             BETR801
# 3     Antwerpen      BE  2019-06-17 06:00:00+00:00             BETR801
# 4     Antwerpen      BE  2019-06-17 05:00:00+00:00             BETR801
# ...         ...     ...                        ...                 ...
# 5267     London      GB  2019-04-09 06:00:00+00:00  London Westminster
# 5268     London      GB  2019-04-09 05:00:00+00:00  London Westminster
# 5269     London      GB  2019-04-09 04:00:00+00:00  London Westminster
# 5270     London      GB  2019-04-09 03:00:00+00:00  London Westminster
# 5271     London      GB  2019-04-09 02:00:00+00:00  London Westminster
#
#      parameter  value   unit
# 0         pm25   18.0  µg/m³
# 1         pm25    6.5  µg/m³
# ...

# %%
no2 = aql_df[aql_df["parameter"] == "now"]

# %%
no2
# Out:
# Empty DataFrame
# Columns: [city, country, date.utc, location, parameter, value, unit]
# Index: []

# %% [markdown]
# ### use 2 measurements (head) for each loacation (groupby)

# %%
no2_subset = no2.sort_index().groupby(["location"]).head(2)

# %%
no2_subset
# Out:
#            city country                   date.utc            location  \
# 1825      Paris      FR  2019-06-21 00:00:00+00:00             FR04014
# 1826      Paris      FR  2019-06-20 23:00:00+00:00             FR04014
# 3501  Antwerpen      BE  2019-06-17 08:00:00+00:00             BETR801
# 3502  Antwerpen      BE  2019-06-17 07:00:00+00:00             BETR801
# 3664     London      GB  2019-06-17 11:00:00+00:00  London Westminster
# 3665     London      GB  2019-06-17 10:00:00+00:00  London Westminster
#
#      parameter  value   unit
# 1825       no2   20.0  µg/m³
# 1826       no2   21.8  µg/m³
# 3501       no2   41.0  µg/m³
# 3502       no2   45.0  µg/m³
# 3664       no2   11.0  µg/m³
# 3665       no2   11.0  µg/m³

# %% [markdown]
# ### I want the values for the three stations as separate columns next to each other

# %%
no2_subset.pivot(columns="location", values="value")
# Out:
# location  BETR801  FR04014  London Westminster
# 1825          NaN     20.0                 NaN
# 1826          NaN     21.8                 NaN
# 3501         41.0      NaN                 NaN
# 3502         45.0      NaN                 NaN
# 3664          NaN      NaN                11.0
# 3665          NaN      NaN                11.0

# %%
no2.head()
# Out:
#        city country                   date.utc location parameter  value  \
# 1825  Paris      FR  2019-06-21 00:00:00+00:00  FR04014       no2   20.0
# 1826  Paris      FR  2019-06-20 23:00:00+00:00  FR04014       no2   21.8
# 1827  Paris      FR  2019-06-20 22:00:00+00:00  FR04014       no2   26.5
# 1828  Paris      FR  2019-06-20 21:00:00+00:00  FR04014       no2   24.9
# 1829  Paris      FR  2019-06-20 20:00:00+00:00  FR04014       no2   21.4
#
#        unit
# 1825  µg/m³
# 1826  µg/m³
# 1827  µg/m³
# 1828  µg/m³
# 1829  µg/m³

# %%
no2.pivot(columns="location", values="value").plot()
# Out:
# <Axes: >

# %% [markdown]
# ### I want the mean concentrations for NO2 and PM2.5 in each of the stations in table from

# %%
aql_df.pivot_table(values="value", index="location",  columns="parameter", aggfunc="mean")
# Out:
# parameter                 no2       pm25
# location
# BETR801             26.950920  23.169492
# FR04014             29.374284        NaN
# London Westminster  29.740050  13.443568

# %%
aql_df.pivot_table(values="value", index="location",  columns="parameter", aggfunc="median")
# Out:
# parameter            no2  pm25
# location
# BETR801             25.0  18.5
# FR04014             26.1   NaN
# London Westminster  28.0   9.0

# %%
aql_df.pivot_table(values="value", index="location",  columns="parameter", aggfunc="mean", margins=True)
# Out:
# parameter                 no2       pm25        All
# location
# BETR801             26.950920  23.169492  24.982353
# FR04014             29.374284        NaN  29.374284
# London Westminster  29.740050  13.443568  21.491708
# All                 29.430316  14.386849  24.222743

# %% [markdown]
# # combine data from multiple tables

# %%
aql1 = pd.read_csv("./Airqualityset1.csv", parse_dates=True)

# %%
aql1
# Out:
#         city country                   date.utc            location parameter  \
# 0      Paris      FR  2019-06-21 00:00:00+00:00             FR04014       no2
# 1      Paris      FR  2019-06-20 23:00:00+00:00             FR04014       no2
# 2      Paris      FR  2019-06-20 22:00:00+00:00             FR04014       no2
# 3      Paris      FR  2019-06-20 21:00:00+00:00             FR04014       no2
# 4      Paris      FR  2019-06-20 20:00:00+00:00             FR04014       no2
# ...      ...     ...                        ...                 ...       ...
# 2063  London      GB  2019-05-07 06:00:00+00:00  London Westminster       no2
# 2064  London      GB  2019-05-07 04:00:00+00:00  London Westminster       no2
# 2065  London      GB  2019-05-07 03:00:00+00:00  London Westminster       no2
# 2066  London      GB  2019-05-07 02:00:00+00:00  London Westminster       no2
# 2067  London      GB  2019-05-07 01:00:00+00:00  London Westminster       no2
#
#       value   unit
# ...

# %%
aql1 = aql1[["date.utc", "location", "parameter", "value"]]

# %%
aql1
# Out:
#                        date.utc            location parameter  value
# 0     2019-06-21 00:00:00+00:00             FR04014       no2   20.0
# 1     2019-06-20 23:00:00+00:00             FR04014       no2   21.8
# 2     2019-06-20 22:00:00+00:00             FR04014       no2   26.5
# 3     2019-06-20 21:00:00+00:00             FR04014       no2   24.9
# 4     2019-06-20 20:00:00+00:00             FR04014       no2   21.4
# ...                         ...                 ...       ...    ...
# 2063  2019-05-07 06:00:00+00:00  London Westminster       no2   26.0
# 2064  2019-05-07 04:00:00+00:00  London Westminster       no2   16.0
# 2065  2019-05-07 03:00:00+00:00  London Westminster       no2   19.0
# 2066  2019-05-07 02:00:00+00:00  London Westminster       no2   19.0
# 2067  2019-05-07 01:00:00+00:00  London Westminster       no2   23.0
#
# [2068 rows x 4 columns]

# %%
aql2 = pd.read_csv("./Airqualityset2.csv", parse_dates=True)

# %%
aql2
# Out:
#            city country                   date.utc            location  \
# 0     Antwerpen      BE  2019-06-18 06:00:00+00:00             BETR801
# 1     Antwerpen      BE  2019-06-17 08:00:00+00:00             BETR801
# 2     Antwerpen      BE  2019-06-17 07:00:00+00:00             BETR801
# 3     Antwerpen      BE  2019-06-17 06:00:00+00:00             BETR801
# 4     Antwerpen      BE  2019-06-17 05:00:00+00:00             BETR801
# ...         ...     ...                        ...                 ...
# 1105     London      GB  2019-05-07 06:00:00+00:00  London Westminster
# 1106     London      GB  2019-05-07 04:00:00+00:00  London Westminster
# 1107     London      GB  2019-05-07 03:00:00+00:00  London Westminster
# 1108     London      GB  2019-05-07 02:00:00+00:00  London Westminster
# 1109     London      GB  2019-05-07 01:00:00+00:00  London Westminster
#
#      parameter  value   unit
# 0         pm25   18.0  µg/m³
# 1         pm25    6.5  µg/m³
# ...

# %%
aql2 = aql2[["date.utc", "location", "parameter", "value"]]

# %%
aql2
# Out:
#                        date.utc            location parameter  value
# 0     2019-06-18 06:00:00+00:00             BETR801      pm25   18.0
# 1     2019-06-17 08:00:00+00:00             BETR801      pm25    6.5
# 2     2019-06-17 07:00:00+00:00             BETR801      pm25   18.5
# 3     2019-06-17 06:00:00+00:00             BETR801      pm25   16.0
# 4     2019-06-17 05:00:00+00:00             BETR801      pm25    7.5
# ...                         ...                 ...       ...    ...
# 1105  2019-05-07 06:00:00+00:00  London Westminster      pm25    9.0
# 1106  2019-05-07 04:00:00+00:00  London Westminster      pm25    8.0
# 1107  2019-05-07 03:00:00+00:00  London Westminster      pm25    8.0
# 1108  2019-05-07 02:00:00+00:00  London Westminster      pm25    8.0
# 1109  2019-05-07 01:00:00+00:00  London Westminster      pm25    8.0
#
# [1110 rows x 4 columns]

# %% [markdown]
# ### I want to combine the measurements of NO2 and PM25, two tables with a similar structure, in a single table

# %%
air_quality_combined = pd.concat([aql1, aql2], axis=0)

# %%
air_quality_combined
# Out:
#                        date.utc            location parameter  value
# 0     2019-06-21 00:00:00+00:00             FR04014       no2   20.0
# 1     2019-06-20 23:00:00+00:00             FR04014       no2   21.8
# 2     2019-06-20 22:00:00+00:00             FR04014       no2   26.5
# 3     2019-06-20 21:00:00+00:00             FR04014       no2   24.9
# 4     2019-06-20 20:00:00+00:00             FR04014       no2   21.4
# ...                         ...                 ...       ...    ...
# 1105  2019-05-07 06:00:00+00:00  London Westminster      pm25    9.0
# 1106  2019-05-07 04:00:00+00:00  London Westminster      pm25    8.0
# 1107  2019-05-07 03:00:00+00:00  London Westminster      pm25    8.0
# 1108  2019-05-07 02:00:00+00:00  London Westminster      pm25    8.0
# 1109  2019-05-07 01:00:00+00:00  London Westminster      pm25    8.0
#
# [3178 rows x 4 columns]

# %%
1110 + 2068
# Out:
# 3178

# %%
aql1.shape
# Out:
# (2068, 4)

# %%
aql2.shape
# Out:
# (1110, 4)

# %%
air_quality_combined.shape
# Out:
# (3178, 4)

# %%
air_quality_combined_vertical = pd.concat([aql1, aql2], axis=1)

# %%
air_quality_combined_vertical
# Out:
#                        date.utc            location parameter  value  \
# 0     2019-06-21 00:00:00+00:00             FR04014       no2   20.0
# 1     2019-06-20 23:00:00+00:00             FR04014       no2   21.8
# 2     2019-06-20 22:00:00+00:00             FR04014       no2   26.5
# 3     2019-06-20 21:00:00+00:00             FR04014       no2   24.9
# 4     2019-06-20 20:00:00+00:00             FR04014       no2   21.4
# ...                         ...                 ...       ...    ...
# 2063  2019-05-07 06:00:00+00:00  London Westminster       no2   26.0
# 2064  2019-05-07 04:00:00+00:00  London Westminster       no2   16.0
# 2065  2019-05-07 03:00:00+00:00  London Westminster       no2   19.0
# 2066  2019-05-07 02:00:00+00:00  London Westminster       no2   19.0
# 2067  2019-05-07 01:00:00+00:00  London Westminster       no2   23.0
#
#                        date.utc location parameter  value
# 0     2019-06-18 06:00:00+00:00  BETR801      pm25   18.0
# ...

# %%
aql_sort = air_quality_combined.sort_values("date.utc")

# %%
aql_sort
# Out:
#                        date.utc            location parameter  value
# 1109  2019-05-07 01:00:00+00:00  London Westminster      pm25    8.0
# 2067  2019-05-07 01:00:00+00:00  London Westminster       no2   23.0
# 1098  2019-05-07 01:00:00+00:00             BETR801       no2   50.5
# 1003  2019-05-07 01:00:00+00:00             FR04014       no2   25.0
# 100   2019-05-07 01:00:00+00:00             BETR801      pm25   12.5
# ...                         ...                 ...       ...    ...
# 2     2019-06-20 22:00:00+00:00             FR04014       no2   26.5
# 102   2019-06-20 23:00:00+00:00  London Westminster      pm25    7.0
# 1     2019-06-20 23:00:00+00:00             FR04014       no2   21.8
# 101   2019-06-21 00:00:00+00:00  London Westminster      pm25    7.0
# 0     2019-06-21 00:00:00+00:00             FR04014       no2   20.0
#
# [3178 rows x 4 columns]

# %% [markdown]
# ### concat using keys3

# %%
air_quality_combined_keys = pd.concat([aql1, aql2], keys=["PM25", "NO2"])

# %%
air_quality_combined_keys.tail()
# Out:
#                            date.utc            location parameter  value
# NO2 1105  2019-05-07 06:00:00+00:00  London Westminster      pm25    9.0
#     1106  2019-05-07 04:00:00+00:00  London Westminster      pm25    8.0
#     1107  2019-05-07 03:00:00+00:00  London Westminster      pm25    8.0
#     1108  2019-05-07 02:00:00+00:00  London Westminster      pm25    8.0
#     1109  2019-05-07 01:00:00+00:00  London Westminster      pm25    8.0

# %% [markdown]
# ### Merging

# %%
aql_loc = pd.read_csv("./Airqualitystationsloc.csv")

# %%
aql_loc.head()
# Out:
#   location  coordinates.latitude  coordinates.longitude
# 0  BELAL01              51.23619                4.38522
# 1  BELHB23              51.17030                4.34100
# 2  BELLD01              51.10998                5.00486
# 3  BELLD02              51.12038                5.02155
# 4  BELR833              51.32766                4.36226

# %%
aql1.head()
# Out:
#                     date.utc location parameter  value
# 0  2019-06-21 00:00:00+00:00  FR04014       no2   20.0
# 1  2019-06-20 23:00:00+00:00  FR04014       no2   21.8
# 2  2019-06-20 22:00:00+00:00  FR04014       no2   26.5
# 3  2019-06-20 21:00:00+00:00  FR04014       no2   24.9
# 4  2019-06-20 20:00:00+00:00  FR04014       no2   21.4

# %%
aql_merge = pd.merge(aql1, aql_loc, how="left", on="location")

# %%
aql_merge
# Out:
#                        date.utc            location parameter  value  \
# 0     2019-06-21 00:00:00+00:00             FR04014       no2   20.0
# 1     2019-06-21 00:00:00+00:00             FR04014       no2   20.0
# 2     2019-06-20 23:00:00+00:00             FR04014       no2   21.8
# 3     2019-06-20 23:00:00+00:00             FR04014       no2   21.8
# 4     2019-06-20 22:00:00+00:00             FR04014       no2   26.5
# ...                         ...                 ...       ...    ...
# 3067  2019-05-07 06:00:00+00:00  London Westminster       no2   26.0
# 3068  2019-05-07 04:00:00+00:00  London Westminster       no2   16.0
# 3069  2019-05-07 03:00:00+00:00  London Westminster       no2   19.0
# 3070  2019-05-07 02:00:00+00:00  London Westminster       no2   19.0
# 3071  2019-05-07 01:00:00+00:00  London Westminster       no2   23.0
#
#       coordinates.latitude  coordinates.longitude
# 0                 48.83724                2.39390
# ...

# %% [markdown]
# ### add the parameters fill description and name, provided by the parameters metadata table to the measurements table

# %%
aql_parameters = pd.read_csv("./Airqualitylong.csv")

# %%
aql_parameters.head()
# Out:
#         city country                   date.utc location parameter  value  \
# 0  Antwerpen      BE  2019-06-18 06:00:00+00:00  BETR801      pm25   18.0
# 1  Antwerpen      BE  2019-06-17 08:00:00+00:00  BETR801      pm25    6.5
# 2  Antwerpen      BE  2019-06-17 07:00:00+00:00  BETR801      pm25   18.5
# 3  Antwerpen      BE  2019-06-17 06:00:00+00:00  BETR801      pm25   16.0
# 4  Antwerpen      BE  2019-06-17 05:00:00+00:00  BETR801      pm25    7.5
#
#     unit
# 0  µg/m³
# 1  µg/m³
# 2  µg/m³
# 3  µg/m³
# 4  µg/m³
